# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Load dataset
df = pd.read_csv('C:\\Users\\Tsebaot\\Desktop\\week 1\\financial-news-prediction-analysis\\data\\raw_analyst_ratings.csv')




# Count articles per publisher
publisher_counts = df['publisher'].value_counts()

# Display the top publishers
print("\nTop Publishers by Article Count:")
print(publisher_counts.head(10))


# Plotting publisher contribution
plt.figure(figsize=(12, 6))
sns.barplot(x=publisher_counts.head(10).index, y=publisher_counts.head(10).values)
plt.title('Top Publishers Contributing to News Feed')
plt.xlabel('Publisher')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# Example: Extracting the first few headlines for each publisher
publisher_counts = df['publisher'].value_counts()
for publisher in publisher_counts.index[:5]:  # Top 5 publishers
    print(f"\nHeadlines from {publisher}:")
    print(df[df['publisher'] == publisher]['headline'].head(5))

    # Function to extract domain from email
def extract_domain(email):
    return email.split('@')[-1] if '@' in email else email

# Apply the function to create a new column for domains
df['domain'] = df['publisher'].apply(extract_domain)


# Count articles per domain
domain_counts = df['domain'].value_counts()


# Display the top domains
print("\nTop Domains by Article Count:")
print(domain_counts.head(10))


# Plotting domain contribution
plt.figure(figsize=(12, 6))
sns.barplot(x=domain_counts.head(10).index, y=domain_counts.head(10).values)
plt.title('Top Domains Contributing to News Feed')
plt.xlabel('Domain')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Top Publishers by Article Count:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64
# Headlines from Paul Quintaro:
# 209    Agilent Reports Purchase Of Genohm, No Terms D...
# 212    UPDATE: Alnylam, Agilent Deal Has Initial Term...
# 213    Alnylam Pharma 8-K Shows Co. Entered Manufactu...
# 225    Agilent Reports Purchase Of Luxcel Biosciences...
# 233    Agilent Sees Q1 Adj. EPS $0.55-$0.57 vs $0.60 ...
# Name: headline, dtype: object
#
# Headlines from Lisa Levin:
# 2                       71 Biggest Movers From Friday
# 3        46 Stocks Moving In Friday's Mid-Day Session
# 9          10 Biggest Price Target Changes For Friday
# 10    30 Stocks Moving in Friday's Pre-Market Session
# ...

# %%
import os
import sys
sys.path.append("../scripts/")  # Add the scripts folder to the path

import utils as util
import eda as eda
import visualization as viz
#import pandas as pd
#from publisher_analysis import count_articles_per_publisher, plot_publisher_contribution, display_headlines
#from domain_analysis import add_domain_column, count_articles_per_domain, plot_domain_contribution

# Load data
all_data_path = '../data/raw_analyst_ratings.csv'
data = util.read_csv_file(all_data_path)
df = data.get("data")

article_counts = eda.count_articles_by_publisher(df)
print("Article Counts per Publisher:\n", article_counts)
# Publisher analysis
viz.plot_top_publishers(article_counts, top_n=10)
#eda.display_headlines(df, publisher_counts, top_n=5)
publisher_counts = df['publisher'].value_counts()
eda.display_headlines(df,publisher_counts)
# Out:
# Article Counts per Publisher:
#  publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64
# Headlines from Paul Quintaro:
# 209    Agilent Reports Purchase Of Genohm, No Terms D...
# 212    UPDATE: Alnylam, Agilent Deal Has Initial Term...
# 213    Alnylam Pharma 8-K Shows Co. Entered Manufactu...
# 225    Agilent Reports Purchase Of Luxcel Biosciences...
# 233    Agilent Sees Q1 Adj. EPS $0.55-$0.57 vs $0.60 ...
# Name: headline, dtype: object
#
# Headlines from Lisa Levin:
# ...
